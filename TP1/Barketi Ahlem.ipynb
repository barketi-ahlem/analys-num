# %% [markdown]
# **<center><h1><font color='blue'>TP1:Analyse_Numérique</h1></center></font>**

# %% [markdown]
# **<font color='green'><h2>Objectifs:</h2></font>**
#
# **Détérminer les valeurs approchées pour chaque méthode**
#
# **Rechercher une telle alpha selon un erreur eps**
#
# **Représenter graphiquement les solutions**

# %% [markdown]
# ## Exercice 1:<h2>
# >On considère le polynôme $p(x) = (x - 1)^6$.
# >
# >En développant on
# >peut écrire ce même polynôme sous la forme
# >$f(x) = x^6 - 6x^5 + 15x^4 - 20x^3 + 15x^2 - 6x + 1.$
# >
# >1) Avec Matlab évaluer $p(x)$ et $f(x)$ pour $x$ allant de $.998$ à
# >$1.002$ en choisissant des pas de $.0001$.
# >
# >2) Faire un graphique de $f(x)$ et $p(x)$. Commenter.

# %% [markdown]
# ### 1) Evaluation de p(x) et f(x)

# %%
def p1(x):
    ''' p(x)=(x-1)⁶'''
    return (x-1)**6 # ** puissance 
def p2(x):
    '''version développer de p(x)'''
    return x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1

# %%
# le calcul de p1(0.998)
print('p1({})={} '.format(0.998,p1(0.998)))
# le calcul de p2(0.998)
print('p2({})={} '.format(0.998,p2(0.998)))
# Out:
# p1(0.998)=6.400000000000034e-17
# p2(0.998)=1.7763568394002505e-15

# %%
p2(3)
# Out:
# 64.0

# %% [markdown]
# ### 2) Représentation graphique de p(x)

# %%
import matplotlib.pyplot as plt
from numpy import linspace

p1=lambda x:  (x-1)**6
x=linspace(0.998,1.002,10)
plt.title("La fonction p1(x)")
plt.plot(p1(x))
plt.xlabel('x')
plt.ylabel('p1(x)')
plt.xlim(0.998,1.002)
plt.plot(x,p1(x))

# %% [markdown]
# ### Représentation graphique de f(x)

# %%
import matplotlib.pyplot as plt
from numpy import linspace

p2=lambda x:  x**6 - 6*x**5 + 15*x**4 - 20*x**3 + 15*x**2 - 6*x + 1
x=np.linspace(0.998,1.002,10)
plt.title("La fonction f(x)")
#x=[0.998 ,0.999 , 1 , 1.001,1.002]
#plt.plot(x)
plt.plot(p2(x))
plt.xlabel('x')
plt.ylabel('f(x)')
plt.xlim(0.998,1.002)
#plt.show()
plt.plot(x,f(x))

# %% [markdown]
# ### Représentation graphique de f(x) et p(x)

# %%
import matplotlib.pyplot as plt
from numpy import linspace

p=lambda x:  (x-1)**6
f=lambda x: x**6-6*x**5+15*x**4-20*x**3+15*x**2-6*x+1
x=linspace(0.998,1.002,10)
plt.title("Les fonction p(x) et f(x)")
plt.plot(x,p(x),'g',x,f(x),'y')
plt.xlabel('les x')
plt.ylabel('p(x)')
plt.xlim(0.998,1.002)
# Out:
# (0.998, 1.002)

# %% [markdown]
# # EXERCICE 2:
#
# On considère l'équation : $$ f(x)=x^3+x^2-3x-3=0$$
# 1) Dessiner la courbe de $f$ dans l'intervalle $[-2;2]$, puis trouver des intervalles convenables pour appliquer la méthode de >bisection.
#
# 2) Utiliser un programme dicho.m qui permettra de trouver les solutions de l'équation $f(x)=0$ avec $eps=0.001$.
#
# 3) Modifier le programme dicho.m pour qu'il donne le nombre d'itération nécessaire pour avoir la solution à $eps$ près.

# %% [markdown]
# ### 1) Représentation graphique de f(x)

# %%
import matplotlib.pyplot as plt
from numpy import linspace
f=lambda x: x**3+x**2-3*x-3
T=linspace(-2,2,41)
plt.title("solution dans [-2:2] ");
plt.xlabel("x")
plt.ylabel ("f(x)")
plt.grid(True)
plt.plot(T,f(T))

# %% [markdown]
# # Daprés le graph de $f$ il existe 3 solutions :
# - $\alpha_1 \in ]-2;-1.5[$
# - $\alpha_2 \in ]-1.5;-0.5[$
# - $\alpha_3 \in ]1.5;2[$

# %% [markdown]
# `[x]=dicho(f,-2,-1.5,0.001)`

# %% [markdown]
# `[x]=diho(f,-2,-1.5,0.001)`

# %% [markdown]
# `[x]=dicho(f,-2,-1.5,0.001)`

# %% [markdown]
# ###  2) la version python de `dicho`

# %%
def dicho(a,b,f,eps):
    m=(a+b)/2
    val = abs(b-a)
    n=0
    while abs(b-a)>eps:
        n+=1
        if f(a)*f(m)<0:
             b=m
        else:
            a=m
        m=(a+b)/2
    print (" nbre d'itérations nécessaires :", n )
    return m

# %% [markdown]
# - $\alpha_1 \in ]-2;-1.5[$
# - $\alpha_2 \in ]-1.5;-0.5[$
# - $\alpha_3 \in ]1.5;2[$

# %%
#alpha1
dicho(-2,-1.5,f,0.0001)
# Out:
#  nbre d'itérations nécessaires : 13
# -1.500030517578125

# %%
#alpha2
Dicho(-1.5,-0.5,f,0.001)
# Out:
#  nbre d'itérations nécessaires : 10
# -0.50048828125

# %%
#alpha3
Dicho(1.5,2,f,0.001)
# Out:
#  nbre d'itérations nécessaires : 9
# 1.99951171875

# %%
import numpy as np
a=-1.5
b=-0.5
p=8 # précision à 10 ^-8 prés
dicho(a,b,f,10**(-p))
# Out:
#  nbre d'itérations nécessaires : 27
# -0.5000000037252903

# %%
interval=[[-2,-1.5],[-1.5,-0.5],[1.5,2]]
for u in interval:
    print(dicho(u[0],u[1],f,10**(-3)))
################################################   
print(dicho(-2,-1.5,f,10**(-3)))
print(dicho(-1.5,-0.5,f,10**(-3)))
print(dicho(1.5,2,f,10**(-3)))
# Out:
#  nbre d'itérations nécessaires : 9
# -1.73193359375
#  nbre d'itérations nécessaires : 10
# -0.50048828125
#  nbre d'itérations nécessaires : 9
# 1.73193359375
#  nbre d'itérations nécessaires : 9
# -1.73193359375
#  nbre d'itérations nécessaires : 10
# -0.50048828125
#  nbre d'itérations nécessaires : 9
# 1.73193359375

# %% [markdown]
# Le nombre d'itération N nécéssaire à la méthode de la dichotomie pour trouver $\alpha$ à $10^{-p}$ prés
#
# $$N \geq E\left(\dfrac{\ln(b-a)+p\ln(10)}{\ln(2)}\right)+1$$

# %%
#alpha 1
dicho(-2,-1.5,f,10**(-5))
#avec eps=10^-5
# Out:
#  nbre d'itérations nécessaires : 16
# -1.7320518493652344

# %%
#alpha 2
dicho(-1.51,-0.5,f,10**(-5))
#avec eps=10^-5
# Out:
#  nbre d'itérations nécessaires : 17
# -1.0000028610229492

# %% [markdown]
# ## Méthode graphique pour la recherche de la solution

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+x**2-3*x-3

t=np.linspace(1.7,1.75,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# # EXERCICE 3:
# >On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# >1) Dessiner la courbe de $f$ dans l'intervalle $[1;2]$, puis trouver une valeur approché de la solution à 0.001 près (En >utilisant la fonction zoom du graphique).
# >
# >2) Vérifier que cette équation est équivalente aux 3 schéma du point fixe suivant:
# >
# >a) $g_1(x)=\frac{1}{2}\sqrt{10-x^3}=x$.
# >
# >b) $g_2(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.
# >
# >c) $g_3(x)=x-x^3-4x^2+10=x$.
# >
# >3) Ecrire puis appliquer  une fonction Matlab que l'on appellera  `pointfixe.m` aux trois schémas précédents en prenant >`x0=1.5;eps=0.001`.
# >
# >4) Quelle est la fonction (parmi $g_1, g_2$ et $g_3$) qui donne la convergence la plus rapide?
# >

# %% [markdown]
# ### Correction <h3>

# %%
# %matplotlib inline
#import mpld3
#mpld3.enable_notebook()
import numpy as np 
import matplotlib.pyplot as plt

f=lambda x:x**3+4*x**2-10

t=np.linspace(1,2,100)
plt.subplot(2,2,1)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.2,1.4,100)
plt.subplot(2,2,2)
plt.plot(t,f(t),'r')
plt.grid(True)
##########################################
t=np.linspace(1.35,1.4,100)
plt.subplot(2,2,3)
plt.plot(t,f(t),'r')
plt.grid(True)
#########################################
t=np.linspace(1.365,1.367,100)
plt.subplot(2,2,4)
plt.plot(t,f(t),'r')
plt.grid(True)

# %% [markdown]
# #### 2) Justification théorique pour la fonction g1

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# a) $g(x)=\frac{1}{2}\sqrt{10-x^3}=x$.

# %% [markdown]
#  $$x^3+4x^2-10=0$$
#
#  $$4x^2=10-x^3$$
#
#  $$2x=\sqrt{10-x^3}$$
#
#  $$x=\frac{1}{2}\sqrt{10-x^3}$$
#
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Calcul symbolique de la dérivée

# %%
from sympy import *
import numpy as np
x, y, z = symbols('x y z')
init_printing(use_unicode=True)
g1=lambda x: 1/2*sqrt(10-x**3)

# %%
dg1=lambdify(x,diff(g1(x),x,1))
dg1(1.365)
# Out:
# -0.5117446282927461

# %% [markdown]
# ### Que pouvez vous conclure à propos des convergences de g1

# %% [markdown]
# **<font color='red'>Réponse: </font> g1 converge localement car |g'(x)|<1**

# %% [markdown]
# ## Justification théoriques pour g2 et g3

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
#
# b) $g(x)=\sqrt{\displaystyle\frac{10}{4+x}}=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2=10$$
# $$x^2(x+4)=10$$
# $$x^2=\frac{10}{x+4}$$
# $$x=\sqrt{\displaystyle\frac{10}{4+x}}$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# On considère l'équation : $$ f(x)=x^3+4x^2-10=0$$
# c) $g(x)=x-x^3-4x^2+10=x$.

# %% [markdown]
# $$x^3+4x^2-10=0$$
# $$x^3+4x^2-10+x-x=0$$
# $$x^3-4x^2+x-x=10$$
# $$x^3-4x^2+x=x+10$$
# $$4x^2+x=x-x^3+10$$
# $$x=x-x^3-4x^2+10$$
# Donc $ f(x)=g(x)$

# %% [markdown]
# ## Etudier théoriquement la convergences de g2 et g3

# %% [markdown]
# ### Donner la solution avec un code python

# %%
import math
f=lambda x:  x**3+4*x**2-10 # la fonction f
g1=lambda x: 1/2*(math.sqrt(10-x**3))
g2=lambda x: math.sqrt(10/(x+4))
g3=lambda x: x-x**3-4*x**2 + 10


def ptfixe(g,x0,eps,sup):
    init=x0
    for i in range(sup):
        x=init
        init=g(x)
        erreur=abs(init-x)
        print(init)
        if erreur<eps:
            return init,i
    print('pas de convergence avec le nombre d''iteration indique')

# %%
ptfixe(g1,1.5,0.001,50)
# Out:
# 1.286953767623375
# 1.4025408035395783
# 1.3454583740232942
# 1.3751702528160383
# 1.360094192761733
# 1.3678469675921328
# 1.3638870038840212
# 1.36591673339004
# 1.364878217193677
# 1.365410061169957
# (1.365410061169957, 9)

# %%
ptfixe(g3,1.5,0.001,5)
# Out:
# -0.875
# 6.732421875
# -469.72001200169325
# 102754555.18738511
# -1.0849338705317464e+24
# pas de convergence avec le nombre diteration indique

# %%
ptfixe(g2,1.5,0.001,60)
# Out:
# 1.348399724926484
# 1.3673763719912828
# 1.364957015402487
# 1.3652647481134421
# (1.3652647481134421, 3)

# %% [markdown]
# ### quelle est la fonction qui donne la convergence la plus rapide ??
#
# Donner le nombre d'itération pour chaque méthode convergente
# + $g_2$ donne le resultat en ? itérations
# + $g_1$ donne le resultat en ?
# + $g_3$ est - elle convergente?

# %% [markdown]
# **g1 donne le résultat en 9 itérations**

# %% [markdown]
# **g2 donne le résultat en 3 itérations**

# %% [markdown]
# **g3 n'est pas convergente**

# %% [markdown]
# **Réponse:la fonction g2 donne la convergence la plus rapide**

# %% [markdown]
# # EXERCICE 4:
# >1) On considère la fonction $f(x)=e^{-x}-x$. Ecrire puis appliquer  une fonction Matlab que l'on appellera `newton.m` à la >fonction $f$, en prenant $x0=0$, $eps=0.001$ .
# >
# >2) Montrer que l'équation $f(x)=0$ admet une solution unique que l'on peut obtenir en utilisant la méthode de Newton à partir >de $x0=1$.

# %% [markdown]
# ### Solution Python

# %%
from math import exp
f=lambda x: exp(-x)-x
fprime=lambda x: -exp(-x)-1
def newton(a,eps):
    x1=a
    x2=x1-f(x1)/fprime(x1)
    while (abs(x1-x2)>eps) :
        x1=x2
        x2=x1-(f(x1)/fprime(x1))
    return x2

# %%
newton(1,0.001)
# Out:
# 0.567143285989123

# %%
newton(0,0.001)
# Out:
# 0.5671431650348622

# %% [markdown]
# **<font color='green'><h2>Conclusion:</h2></font>**
#
#    on peut conclure qu'analytiquement on ne peut pas donner la valeur exacte de alpha.C'est pour quoi on a recours à des méthode itérative pour espérer a donner une valeur approché de alpha.
